# %% [markdown]
# # Database Admin 101 - Lab
#
# ## Introduction
#
# In this lab, you'll go through the process of designing and creating a database. From there, you'll begin to populate this table with mock data provided to you.
#
# ## Objectives
#
# You will be able to:
#
# * Use knowledge of the structure of databases to create a database and populate it

# %% [markdown]
# ## The Scenario
#
# You are looking to design a database for a school that will house various information from student grades to contact information, class roster lists and attendance. First, think of how you would design such a database. What tables would you include? What columns would each table have? What would be the primary means to join said tables?

# %% [markdown]
# ## Creating the Database
#
# Now that you've put a little thought into how you might design your database, it's time to go ahead and create it! Start by import the necessary packages. Then, create a database called **school.sqlite**.

# %%
# Import necessary packages
import pandas as pd
import sqlite3

# %%
# Create the database school.sqlite 
conn = sqlite3.connect('school.sqlite')
cur = conn.cursor()

# %% [markdown]
# ## Create a Table for Contact Information
#
# Create a table called contactInfo to house contact information for both students and staff. Be sure to include columns for first name, last name, role (student/staff), telephone number, street, city, state, and zipcode. Be sure to also create a primary key for the table.

# %%
# Your code here

#create the contactsinfo
cur.execute('''
    CREATE TABLE contactInfo (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        first_name TEXT NOT NULL,
        last_name TEXT NOT NULL,
        role TEXT NOT NULL,
        telephone_number TEXT,
        street TEXT,
        city TEXT,
        state TEXT,
        zipcode TEXT
    )
''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /Users/brianrono/Moringa DS/Phase 2/SQL/Labs/dsc-database-admin-101-lab/index.ipynb Cell 7 line 4
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> # Your code here
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a>
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> #create the contactsinfo
# ----> <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> cur.execute('''
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a>     CREATE TABLE contactInfo (
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a>         id INTEGER PRIMARY KEY AUTOINCREMENT,
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a>         first_name TEXT NOT NULL,
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a>         last_name TEXT NOT NULL,
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#W6sZmlsZQ%3D%3D?line=8'>9</a>         role TEXT NOT NULL,
#      <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#W6sZmlsZQ%3D%3D?line=9'>10</a>         telephone_number TEXT,
#      <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#W6sZmlsZQ%3D%3D?line=10'>11</a>         street TEXT,
#      <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#W6sZmlsZQ%3D%3D?line=11'>12</a>         city TEXT,
#      <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#W6sZmlsZQ%3D%3D?line=12'>13</a>         state TEXT,
#      <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#W6sZmlsZQ%3D%3D?line=13'>14</a>         zipcode TEXT
#      <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#W6sZmlsZQ%3D%3D?line=14'>15</a>     )
#      <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#W6sZmlsZQ%3D%3D?line=15'>16</a> ''')
#
# OperationalError: table contactInfo already exists

# %% [markdown]
# ## Populate the Table
#
# Below, code is provided for you in order to load a list of dictionaries. Briefly examine the list. Each dictionary in the list will serve as an entry for your contact info table. Once you've briefly investigated the structure of this data, write a for loop to iterate through the list and create an entry in your table for each person's contact info.

# %%
# Load the list of dictionaries; just run this cell
import pickle

with open('contact_list.pickle', 'rb') as f:
    contacts = pickle.load(f)

# %%
# Iterate over the contact list and populate the contactInfo table here

conn = sqlite3.connect('school.sqlite')
cur = conn.cursor()

for contact in contacts:
    cur.execute('''
        INSERT INTO contactInfo (first_name, last_name, role, telephone_number, street, city, state, zipcode)
        VALUES (?, ?, ?, ?, ?, ?, ?, ?);
    ''', (contact['firstName'], contact['lastName'], contact['role'], contact['telephone '], contact['street'], contact['city'], contact['state'], contact['zipcode ']))

# %% [markdown]
# **Query the Table to Ensure it is populated**

# %%
# Your code here 

cur.execute('SELECT * FROM contactInfo')
rows = cur.fetchall()

#print the rows 
for row in rows:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/brianrono/Moringa DS/Phase 2/SQL/Labs/dsc-database-admin-101-lab/index.ipynb Cell 12 line 3
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> # Your code here
# ----> <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> cur.execute('SELECT * FROM contactInfo')
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> rows = cur.fetchall()
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a> #print the rows
#
# NameError: name 'cur' is not defined

# %% [markdown]
# ## Commit Your Changes to the Database
#
# Persist your changes by committing them to the database.

# %%
# Your code here
# Query the contactInfo table to ensure it is populated
cur.execute('SELECT * FROM contactInfo')
rows = cur.fetchall()

# Print the results
for row in rows:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /Users/brianrono/Moringa DS/Phase 2/SQL/Labs/dsc-database-admin-101-lab/index.ipynb Cell 14 line 3
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> # Your code here
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> # Query the contactInfo table to ensure it is populated
# ----> <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> cur.execute('SELECT * FROM contactInfo')
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> rows = cur.fetchall()
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a> # Print the results
#
# ProgrammingError: Cannot operate on a closed database.

# %% [markdown]
# ## Create a Table for Student Grades
#
# Create a new table in the database called "grades". In the table, include the following fields: userId, courseId, grade.
#
# ** This problem is a bit more tricky and will require a dual key. (A nuance you have yet to see.)
# Here's how to do that:
#
# ```SQL
# CREATE TABLE table_name(
#    column_1 INTEGER NOT NULL,
#    column_2 INTEGER NOT NULL,
#    ...
#    PRIMARY KEY(column_1,column_2,...)
# );
# ```

# %%
# Create the grades table
cur.execute('''
    CREATE TABLE grades (
        userId INTEGER NOT NULL,
        courseId INTEGER NOT NULL,
        grade TEXT,
        PRIMARY KEY (userId, courseId)
    )
''')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /Users/brianrono/Moringa DS/Phase 2/SQL/Labs/dsc-database-admin-101-lab/index.ipynb Cell 16 line 2
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> # Create the grades table
# ----> <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> cur.execute('''
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a>     CREATE TABLE grades (
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a>         userId INTEGER NOT NULL,
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a>         courseId INTEGER NOT NULL,
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a>         grade TEXT,
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X21sZmlsZQ%3D%3D?line=6'>7</a>         PRIMARY KEY (userId, courseId)
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X21sZmlsZQ%3D%3D?line=7'>8</a>     )
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X21sZmlsZQ%3D%3D?line=8'>9</a> ''')
#      <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X21sZmlsZQ%3D%3D?line=10'>11</a> # Commit the changes and close the connection
#      <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X21sZmlsZQ%3D%3D?line=11'>12</a> conn.commit()
#
# ProgrammingError: Cannot operate on a closed database.

# %% [markdown]
# ## Remove Duplicate Entries
#
# An analyst just realized that there is a duplicate entry in the contactInfo table! Find and remove it.

# %%
# Find the duplicate entry
cur.execute('''
    SELECT first_name, last_name, role, telephone_number, street, city, state, zipcode, COUNT(*)
    FROM contactInfo
    GROUP BY first_name, last_name, role, telephone_number, street, city, state, zipcode
    HAVING COUNT(*) > 1
''')
duplicates = cur.fetchall()

# Print the duplicates
for row in duplicates:
    print(row)

# Remove the duplicate entries while keeping one instance of each
for row in duplicates:
    cur.execute('''
        DELETE FROM contactInfo
        WHERE rowid NOT IN (
            SELECT MIN(rowid)
            FROM contactInfo
            GROUP BY first_name, last_name, role, telephone_number, street, city, state, zipcode
        )
    ''')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /Users/brianrono/Moringa DS/Phase 2/SQL/Labs/dsc-database-admin-101-lab/index.ipynb Cell 18 line 2
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> # Find the duplicate entry
# ----> <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> cur.execute('''
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a>     SELECT first_name, last_name, role, telephone_number, street, city, state, zipcode, COUNT(*)
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a>     FROM contactInfo
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a>     GROUP BY first_name, last_name, role, telephone_number, street, city, state, zipcode
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X23sZmlsZQ%3D%3D?line=5'>6</a>     HAVING COUNT(*) > 1
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X23sZmlsZQ%3D%3D?line=6'>7</a> ''')
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X23sZmlsZQ%3D%3D?line=7'>8</a> duplicates = cur.fetchall()
#      <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X23sZmlsZQ%3D%3D?line=9'>10</a> # Print the duplicates
#
# ProgrammingError: Cannot operate on a closed database.

# %%
# Delete the duplicate entry
cur.execute('''
    DELETE FROM contactInfo
    WHERE rowid NOT IN (
        SELECT MIN(rowid)
        FROM contactInfo
        GROUP BY first_name, last_name, role, telephone_number, street, city, state, zipcode
    )
''')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /Users/brianrono/Moringa DS/Phase 2/SQL/Labs/dsc-database-admin-101-lab/index.ipynb Cell 19 line 2
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> # Delete the duplicate entry
# ----> <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> cur.execute('''
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X24sZmlsZQ%3D%3D?line=2'>3</a>     DELETE FROM contactInfo
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X24sZmlsZQ%3D%3D?line=3'>4</a>     WHERE rowid NOT IN (
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X24sZmlsZQ%3D%3D?line=4'>5</a>         SELECT MIN(rowid)
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X24sZmlsZQ%3D%3D?line=5'>6</a>         FROM contactInfo
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X24sZmlsZQ%3D%3D?line=6'>7</a>         GROUP BY first_name, last_name, role, telephone_number, street, city, state, zipcode
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X24sZmlsZQ%3D%3D?line=7'>8</a>     )
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X24sZmlsZQ%3D%3D?line=8'>9</a> ''')
#      <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X24sZmlsZQ%3D%3D?line=10'>11</a> # Commit the changes and close the connection
#      <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X24sZmlsZQ%3D%3D?line=11'>12</a> conn.commit()
#
# ProgrammingError: Cannot operate on a closed database.

# %%
# Check that the duplicate entry was removed
cur.execute('''
    SELECT first_name, last_name, role, telephone_number, street, city, state, zipcode, COUNT(*)
    FROM contactInfo
    GROUP BY first_name, last_name, role, telephone_number, street, city, state, zipcode
    HAVING COUNT(*) > 1
''')
duplicates = cur.fetchall()

if not duplicates:
    print("No duplicate entries found.")
else:
    print("Duplicate entries still exist:")
    for row in duplicates:
        print(row)

# %% [markdown]
# ## Updating an Address
#
# Ed Lyman just moved to `2910 Simpson Avenue York, PA 17403`. Update his address accordingly.

# %%
# Update Ed's address
cur.execute('''
    UPDATE contactInfo
    SET street = ?, city = ?, state = ?, zipcode = ?
    WHERE first_name = ? AND last_name = ?
''', ('2910 Simpson Avenue', 'York', 'PA', '17403', 'Ed', 'Lyman'))
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /Users/brianrono/Moringa DS/Phase 2/SQL/Labs/dsc-database-admin-101-lab/index.ipynb Cell 22 line 2
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> # Update Ed's address
# ----> <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> cur.execute('''
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X30sZmlsZQ%3D%3D?line=2'>3</a>     UPDATE contactInfo
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X30sZmlsZQ%3D%3D?line=3'>4</a>     SET street = ?, city = ?, state = ?, zipcode = ?
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X30sZmlsZQ%3D%3D?line=4'>5</a>     WHERE first_name = ? AND last_name = ?
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X30sZmlsZQ%3D%3D?line=5'>6</a> ''', ('2910 Simpson Avenue', 'York', 'PA', '17403', 'Ed', 'Lyman'))
#
# ProgrammingError: Cannot operate on a closed database.

# %%
# Query the database to ensure the change was made
cur.execute('''
    SELECT * FROM contactInfo
    WHERE first_name = ? AND last_name = ?
''', ('Ed', 'Lyman'))
rows = cur.fetchall()

# Print the results
for row in rows:
    print(row)

# %% [markdown]
# ## Commit Your Changes to the Database
#
# Once again, persist your changes by committing them to the database.

# %%
# Your code here
conn.commit()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /Users/brianrono/Moringa DS/Phase 2/SQL/Labs/dsc-database-admin-101-lab/index.ipynb Cell 25 line 2
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> # Your code here
# ----> <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a> conn.commit()
#       <a href='vscode-notebook-cell:/Users/brianrono/Moringa%20DS/Phase%202/SQL/Labs/dsc-database-admin-101-lab/index.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a> conn.close()
#
# ProgrammingError: Cannot operate on a closed database.

# %% [markdown]
# ## Summary
#
# While there's certainly more to do with setting up and managing this database, you got a taste for creating, populating, and maintaining databases! Feel free to continue fleshing out this exercise for more practice.
